jpg
#  extracting: facial_expressions2/Training/Sad/Sad-998.jpg
#  extracting: facial_expressions2/Training/Sad/Sad-999.jpg

# %%
# Out:
# '/content'

# %%
#checking count of images
for exp in os.listdir("./facial_expressions2/Training"):
  print(str(len(os.listdir("./facial_expressions2/Training/" + exp)))+ " "+ exp+ " total images")
# Out:
# 3995 Angry total images
# 7215 Happy total images
# 4830 Sad total images

# %%
#creating access to data sets
datasets = ['./facial_expressions2/Training','./facial_expressions2/Testing']
output = []
class_names = ['Angry','Happy','Sad']
class_name_labels = {class_name:j for j,class_name in enumerate(class_names)}
nb_classes = len(class_names)
class_name_labels
# Out:
# {'Angry': 0, 'Happy': 1, 'Sad': 2}

# %%
#Function to load data
def load_data():
    for dataset in datasets:
        print("Loading {}".format(dataset))
        images,labels = [],[]
        for folder in os.listdir(dataset):
            label = class_name_labels[folder]
            for file in tqdm(os.listdir(os.path.join(dataset,folder))):
                img_path = os.path.join(os.path.join(dataset,folder),file)
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                img = cv2.resize(img,(125,125))
                images.append(img)
                labels.append(label)
                pass
            pass
        images = np.array(images,dtype=np.float32)
        labels = np.array(labels,dtype=np.float32)
        output.append((images,labels))
        pass
    return output
    pass

# %%
(train_images, train_labels),(test_images, test_labels) = load_data()
# Out:
# Loading ./facial_expressions2/Training
# 100%|██████████| 3995/3995 [00:00<00:00, 7995.06it/s]
# 100%|██████████| 7215/7215 [00:00<00:00, 8535.97it/s]
# 100%|██████████| 4830/4830 [00:00<00:00, 8993.80it/s]
# Loading ./facial_expressions2/Testing
# 100%|██████████| 958/958 [00:00<00:00, 9038.84it/s]
# 100%|██████████| 1774/1774 [00:00<00:00, 9501.38it/s]
# 100%|██████████| 1247/1247 [00:00<00:00, 9482.72it/s]

# %%
#setting up data frame
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]
_, train_count = np.unique(train_labels,return_counts=True)
_, test_count = np.unique(test_labels,return_counts=True)
df = pd.DataFrame(data = (train_count,test_count))
df = df.T
df['Name'] = class_names
df
# Out:
#       0     1   Name
# 0  3995   958  Angry
# 1  7215  1774  Happy
# 2  4830  1247    Sad

# %%
plt.pie(train_count,
       explode=(0,0,0),
       labels=class_names,
       autopct = '%1.1f%%')
plt.axis('equal')
plt.title("Proportion of train data")
plt.show()

# %%
plt.pie(test_count,
       explode=(0,0,0),
       labels=class_names,
       autopct = '%1.1f%%')
plt.axis('equal')
plt.title("Proportion of test data")
plt.show()

# %%
batch_size = 64
datagen_train = ImageDataGenerator(rescale = 1./255)
datagen_test = ImageDataGenerator(rescale = 1./255)
train_generator = datagen_train.flow_from_directory("./facial_expressions2/Training",
                                                   target_size = Image_size,
                                                   color_mode="grayscale",
                                                   batch_size=batch_size,
                                                   class_mode = "categorical",
                                                   shuffle=True)
test_generator = datagen_test.flow_from_directory("./facial_expressions2/Testing",
                                                 target_size = Image_size,
                                                 color_mode = "grayscale",
                                                 batch_size = batch_size,
                                                 class_mode = "categorical",
                                                 shuffle=True)
# Out:
# Found 16040 images belonging to 3 classes.
# Found 3979 images belonging to 3 classes.

# %%
#additional keras imports
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam,SGD
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Sequential,Input,Model

from keras.initializers import *

# %%
#functions to build CNN
def identity_block(X,k,filters,stage,block):
    conv_name_base = 'res_'+str(stage)+block+'_branch'
    bn_name_base = 'bn_'+str(stage)+block+'_branch'
    F1,F2,F3 = filters
    X_shortcut = X
    # First Component of Main Path
    X = Conv2D(filters=F1,kernel_size=(3,3),strides=(1,1),
               padding='same',name=conv_name_base+'2a',
               kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(name=bn_name_base+'2a')(X)
    X = Activation('relu')(X)
    # Second Component of Main Path
    X = Conv2D(filters=F2,kernel_size=(k,k),strides=(1,1),
              padding='same',name=conv_name_base+'2b',
              kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(name=bn_name_base+'2b')(X)
    X = Activation('relu')(X)
    # Third Component of Main Path
    X = Conv2D(filters=F3,kernel_size=(3,3),strides=(1,1),
              padding='same',name=conv_name_base+'2c',
              kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(name=bn_name_base+'2c')(X)
    X = Add()([X,X_shortcut])
    X = Activation('relu')(X)
    return X
    pass

def convolutional_block(X,k,filters,stage,block,s=2):
    conv_base_name = 'res_' + str(stage) + block + '_branch'
    bn_base_name = 'bn_' + str(stage) + block + '_branch'
    F1,F2,F3 = filters
    X_shortcut = X
    ### MAIN PATH ###
    # First component of main path
    X = Conv2D(filters=F1,kernel_size=(3,3),strides=(s,s),
              padding='same',name=conv_base_name+'2a',
              kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(name=bn_base_name+'2a')(X)
    X = Activation('relu')(X)
    # Second Component of main path
    X = Conv2D(filters=F2,kernel_size=(k,k),strides=(1,1),
              padding='same',name=conv_base_name+'2b',
              kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(name=bn_base_name+'2b')(X)
    X = Activation('relu')(X)
    # Third Component of main path
    X = Conv2D(filters=F3,kernel_size=(3,3),strides=(1,1),
              padding='same',name=conv_base_name+'2c',
              kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(name=bn_base_name+'2c')(X)
    # Shortcut path
    X_shortcut = Conv2D(filters=F3,kernel_size=(1,1),strides=(s,s),
                       padding='same',name=conv_base_name+'1',
                       kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(name=bn_base_name+'1')(X_shortcut)
    X = Add()([X,X_shortcut])
    X = Activation('relu')(X)
    return X
    pass

def ResNet(input_shape,classes):
    X_input = Input(input_shape)
    X = ZeroPadding2D((3,3))(X_input)
    # Stage 1
    X = Conv2D(64,(3,3),strides=(2,2),name='conv1',kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3,3))(X)
    # Stage 2
    X = convolutional_block(X,k=3,filters=[32,32,64],stage=2,block='A',s=1)
    X = identity_block(X,k=3,filters=[32,32,64],stage=2,block='B')
    X = identity_block(X,k=3,filters=[32,32,64],stage=2,block='C')
    # Stage 3
    X = convolutional_block(X,k=3,filters=[64,64,128],stage=3,block='A',s=1)
    X = identity_block(X,k=5,filters=[64,64,128],stage=3,block='B')
    X = identity_block(X,k=3,filters=[64,64,128],stage=3,block='C')
    X = identity_block(X,k=5,filters=[64,64,128],stage=3,block='D')
    # Stage 4
    X = convolutional_block(X,k=5,filters=[128,128,256],stage=4,block='A',s=1)
    X = identity_block(X,k=3,filters=[128,128,256],stage=4,block='B')
    X = identity_block(X,k=3,filters=[128,128,256],stage=4,block='C')
    X = AveragePooling2D((2,2),name='avg_pooling1')(X)
    X = Flatten()(X)
    X = Dense(classes,activation='softmax',name='fc'+str(classes),
              kernel_initializer=glorot_uniform(seed=0))(X)
    model = Model(inputs=X_input,outputs=X,name='ResNet')
    return model
    pass

# %%
model = ResNet(input_shape=(125,125,1),classes=3)

# %%
model.summary()
# Out:
# Model: "ResNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 125, 125, 1) 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 131, 131, 1)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 65, 65, 64)   640         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 65, 65, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 65, 65, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 21, 21, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# res_2A_branch2a (Conv2D)        (None, 21, 21, 32)   18464       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn_2A_branch2a (BatchNormalizat (None, 21, 21, 32)   128         res_2A_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 21, 21, 32)   0           bn_2A_branch2a[0][0]
# __________________________________________________________________________________________________
# res_2A_branch2b (Conv2D)        (None, 21, 21, 32)   9248        activation_32[0][0]
# __________________________________________________________________________________________________
# bn_2A_branch2b (BatchNormalizat (None, 21, 21, 32)   128         res_2A_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 21, 21, 32)   0           bn_2A_branch2b[0][0]
# __________________________________________________________________________________________________
# res_2A_branch2c (Conv2D)        (None, 21, 21, 64)   18496       activation_33[0][0]
# __________________________________________________________________________________________________
# res_2A_branch1 (Conv2D)         (None, 21, 21, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn_2A_branch2c (BatchNormalizat (None, 21, 21, 64)   256         res_2A_branch2c[0][0]
# __________________________________________________________________________________________________
# bn_2A_branch1 (BatchNormalizati (None, 21, 21, 64)   256         res_2A_branch1[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 21, 21, 64)   0           bn_2A_branch2c[0][0]
#                                                                  bn_2A_branch1[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 21, 21, 64)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res_2B_branch2a (Conv2D)        (None, 21, 21, 32)   18464       activation_34[0][0]
# __________________________________________________________________________________________________
# bn_2B_branch2a (BatchNormalizat (None, 21, 21, 32)   128         res_2B_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 21, 21, 32)   0           bn_2B_branch2a[0][0]
# __________________________________________________________________________________________________
# res_2B_branch2b (Conv2D)        (None, 21, 21, 32)   9248        activation_35[0][0]
# __________________________________________________________________________________________________
# bn_2B_branch2b (BatchNormalizat (None, 21, 21, 32)   128         res_2B_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 21, 21, 32)   0           bn_2B_branch2b[0][0]
# __________________________________________________________________________________________________
# res_2B_branch2c (Conv2D)        (None, 21, 21, 64)   18496       activation_36[0][0]
# __________________________________________________________________________________________________
# bn_2B_branch2c (BatchNormalizat (None, 21, 21, 64)   256         res_2B_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 21, 21, 64)   0           bn_2B_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 21, 21, 64)   0           add_11[0][0]
# __________________________________________________________________________________________________
# res_2C_branch2a (Conv2D)        (None, 21, 21, 32)   18464       activation_37[0][0]
# __________________________________________________________________________________________________
# bn_2C_branch2a (BatchNormalizat (None, 21, 21, 32)   128         res_2C_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 21, 21, 32)   0           bn_2C_branch2a[0][0]
# __________________________________________________________________________________________________
# res_2C_branch2b (Conv2D)        (None, 21, 21, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# bn_2C_branch2b (BatchNormalizat (None, 21, 21, 32)   128         res_2C_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 21, 21, 32)   0           bn_2C_branch2b[0][0]
# __________________________________________________________________________________________________
# res_2C_branch2c (Conv2D)        (None, 21, 21, 64)   18496       activation_39[0][0]
# __________________________________________________________________________________________________
# bn_2C_branch2c (BatchNormalizat (None, 21, 21, 64)   256         res_2C_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 21, 21, 64)   0           bn_2C_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 21, 21, 64)   0           add_12[0][0]
# __________________________________________________________________________________________________
# res_3A_branch2a (Conv2D)        (None, 21, 21, 64)   36928       activation_40[0][0]
# __________________________________________________________________________________________________
# bn_3A_branch2a (BatchNormalizat (None, 21, 21, 64)   256         res_3A_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 21, 21, 64)   0           bn_3A_branch2a[0][0]
# __________________________________________________________________________________________________
# res_3A_branch2b (Conv2D)        (None, 21, 21, 64)   36928       activation_41[0][0]
# __________________________________________________________________________________________________
# bn_3A_branch2b (BatchNormalizat (None, 21, 21, 64)   256         res_3A_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 21, 21, 64)   0           bn_3A_branch2b[0][0]
# __________________________________________________________________________________________________
# res_3A_branch2c (Conv2D)        (None, 21, 21, 128)  73856       activation_42[0][0]
# __________________________________________________________________________________________________
# res_3A_branch1 (Conv2D)         (None, 21, 21, 128)  8320        activation_40[0][0]
# __________________________________________________________________________________________________
# bn_3A_branch2c (BatchNormalizat (None, 21, 21, 128)  512         res_3A_branch2c[0][0]
# __________________________________________________________________________________________________
# bn_3A_branch1 (BatchNormalizati (None, 21, 21, 128)  512         res_3A_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 21, 21, 128)  0           bn_3A_branch2c[0][0]
#                                                                  bn_3A_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 21, 21, 128)  0           add_13[0][0]
# __________________________________________________________________________________________________
# res_3B_branch2a (Conv2D)        (None, 21, 21, 64)   73792       activation_43[0][0]
# __________________________________________________________________________________________________
# bn_3B_branch2a (BatchNormalizat (None, 21, 21, 64)   256         res_3B_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 21, 21, 64)   0           bn_3B_branch2a[0][0]
# __________________________________________________________________________________________________
# res_3B_branch2b (Conv2D)        (None, 21, 21, 64)   102464      activation_44[0][0]
# __________________________________________________________________________________________________
# bn_3B_branch2b (BatchNormalizat (None, 21, 21, 64)   256         res_3B_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 21, 21, 64)   0           bn_3B_branch2b[0][0]
# __________________________________________________________________________________________________
# res_3B_branch2c (Conv2D)        (None, 21, 21, 128)  73856       activation_45[0][0]
# __________________________________________________________________________________________________
# bn_3B_branch2c (BatchNormalizat (None, 21, 21, 128)  512         res_3B_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 21, 21, 128)  0           bn_3B_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 21, 21, 128)  0           add_14[0][0]
# __________________________________________________________________________________________________
# res_3C_branch2a (Conv2D)        (None, 21, 21, 64)   73792       activation_46[0][0]
# __________________________________________________________________________________________________
# bn_3C_branch2a (BatchNormalizat (None, 21, 21, 64)   256         res_3C_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 21, 21, 64)   0           bn_3C_branch2a[0][0]
# __________________________________________________________________________________________________
# res_3C_branch2b (Conv2D)        (None, 21, 21, 64)   36928       activation_47[0][0]
# __________________________________________________________________________________________________
# bn_3C_branch2b (BatchNormalizat (None, 21, 21, 64)   256         res_3C_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 21, 21, 64)   0           bn_3C_branch2b[0][0]
# __________________________________________________________________________________________________
# res_3C_branch2c (Conv2D)        (None, 21, 21, 128)  73856       activation_48[0][0]
# __________________________________________________________________________________________________
# bn_3C_branch2c (BatchNormalizat (None, 21, 21, 128)  512         res_3C_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 21, 21, 128)  0           bn_3C_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 21, 21, 128)  0           add_15[0][0]
# __________________________________________________________________________________________________
# res_3D_branch2a (Conv2D)        (None, 21, 21, 64)   73792       activation_49[0][0]
# __________________________________________________________________________________________________
# bn_3D_branch2a (BatchNormalizat (None, 21, 21, 64)   256         res_3D_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 21, 21, 64)   0           bn_3D_branch2a[0][0]
# __________________________________________________________________________________________________
# res_3D_branch2b (Conv2D)        (None, 21, 21, 64)   102464      activation_50[0][0]
# __________________________________________________________________________________________________
# bn_3D_branch2b (BatchNormalizat (None, 21, 21, 64)   256         res_3D_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 21, 21, 64)   0           bn_3D_branch2b[0][0]
# __________________________________________________________________________________________________
# res_3D_branch2c (Conv2D)        (None, 21, 21, 128)  73856       activation_51[0][0]
# __________________________________________________________________________________________________
# bn_3D_branch2c (BatchNormalizat (None, 21, 21, 128)  512         res_3D_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 21, 21, 128)  0           bn_3D_branch2c[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 21, 21, 128)  0           add_16[0][0]
# __________________________________________________________________________________________________
# res_4A_branch2a (Conv2D)        (None, 21, 21, 128)  147584      activation_52[0][0]
# __________________________________________________________________________________________________
# bn_4A_branch2a (BatchNormalizat (None, 21, 21, 128)  512         res_4A_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 21, 21, 128)  0           bn_4A_branch2a[0][0]
# __________________________________________________________________________________________________
# res_4A_branch2b (Conv2D)        (None, 21, 21, 128)  409728      activation_53[0][0]
# __________________________________________________________________________________________________
# bn_4A_branch2b (BatchNormalizat (None, 21, 21, 128)  512         res_4A_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 21, 21, 128)  0           bn_4A_branch2b[0][0]
# __________________________________________________________________________________________________
# res_4A_branch2c (Conv2D)        (None, 21, 21, 256)  295168      activation_54[0][0]
# __________________________________________________________________________________________________
# res_4A_branch1 (Conv2D)         (None, 21, 21, 256)  33024       activation_52[0][0]
# __________________________________________________________________________________________________
# bn_4A_branch2c (BatchNormalizat (None, 21, 21, 256)  1024        res_4A_branch2c[0][0]
# __________________________________________________________________________________________________
# bn_4A_branch1 (BatchNormalizati (None, 21, 21, 256)  1024        res_4A_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 21, 21, 256)  0           bn_4A_branch2c[0][0]
#                                                                  bn_4A_branch1[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 21, 21, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# res_4B_branch2a (Conv2D)        (None, 21, 21, 128)  295040      activation_55[0][0]
# __________________________________________________________________________________________________
# bn_4B_branch2a (BatchNormalizat (None, 21, 21, 128)  512         res_4B_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 21, 21, 128)  0           bn_4B_branch2a[0][0]
# __________________________________________________________________________________________________
# res_4B_branch2b (Conv2D)        (None, 21, 21, 128)  147584      activation_56[0][0]
# __________________________________________________________________________________________________
# bn_4B_branch2b (BatchNormalizat (None, 21, 21, 128)  512         res_4B_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 21, 21, 128)  0           bn_4B_branch2b[0][0]
# __________________________________________________________________________________________________
# res_4B_branch2c (Conv2D)        (None, 21, 21, 256)  295168      activation_57[0][0]
# __________________________________________________________________________________________________
# bn_4B_branch2c (BatchNormalizat (None, 21, 21, 256)  1024        res_4B_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 21, 21, 256)  0           bn_4B_branch2c[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 21, 21, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# res_4C_branch2a (Conv2D)        (None, 21, 21, 128)  295040      activation_58[0][0]
# __________________________________________________________________________________________________
# bn_4C_branch2a (BatchNormalizat (None, 21, 21, 128)  512         res_4C_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 21, 21, 128)  0           bn_4C_branch2a[0][0]
# __________________________________________________________________________________________________
# res_4C_branch2b (Conv2D)        (None, 21, 21, 128)  147584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn_4C_branch2b (BatchNormalizat (None, 21, 21, 128)  512         res_4C_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 21, 21, 128)  0           bn_4C_branch2b[0][0]
# __________________________________________________________________________________________________
# res_4C_branch2c (Conv2D)        (None, 21, 21, 256)  295168      activation_60[0][0]
# __________________________________________________________________________________________________
# bn_4C_branch2c (BatchNormalizat (None, 21, 21, 256)  1024        res_4C_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 21, 21, 256)  0           bn_4C_branch2c[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 21, 21, 256)  0           add_19[0][0]
# __________________________________________________________________________________________________
# avg_pooling1 (AveragePooling2D) (None, 10, 10, 256)  0           activation_61[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 25600)        0           avg_pooling1[0][0]
# __________________________________________________________________________________________________
# fc3 (Dense)                     (None, 3)            76803       flatten_1[0][0]
# ==================================================================================================
# Total params: 3,435,971
# Trainable params: 3,429,059
# Non-trainable params: 6,912
# __________________________________________________________________________________________________

# %%
opt = Adam(learning_rate=0.003)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5",monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')
callbacks_list=[checkpoint]
epochs = 25
# batch_size = 128
history = model.fit_generator(generator=train_generator,
                             steps_per_epoch=train_generator.n//train_generator.batch_size,
                             epochs=epochs,
                             validation_data=test_generator,
                             validation_steps = test_generator.n//test_generator.batch_size,
                             callbacks=callbacks_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/25
# 250/250 [==============================] - 63s 219ms/step - loss: 3.5652 - accuracy: 0.4069 - val_loss: 1.1004 - val_accuracy: 0.3259
#
# Epoch 00001: val_accuracy improved from -inf to 0.32586, saving model to model_weights.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.8776 - accuracy: 0.5851 - val_loss: 0.9599 - val_accuracy: 0.5559
#
# Epoch 00002: val_accuracy improved from 0.32586 to 0.55595, saving model to model_weights.h5
# Epoch 3/25
# 250/250 [==============================] - 52s 207ms/step - loss: 0.7403 - accuracy: 0.6652 - val_loss: 0.7192 - val_accuracy: 0.6787
#
# Epoch 00003: val_accuracy improved from 0.55595 to 0.67868, saving model to model_weights.h5
# Epoch 4/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.6672 - accuracy: 0.6998 - val_loss: 1.0593 - val_accuracy: 0.5930
#
# Epoch 00004: val_accuracy did not improve from 0.67868
# Epoch 5/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.6171 - accuracy: 0.7332 - val_loss: 1.0819 - val_accuracy: 0.4677
#
# Epoch 00005: val_accuracy did not improve from 0.67868
# Epoch 6/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.5642 - accuracy: 0.7580 - val_loss: 0.6965 - val_accuracy: 0.6913
#
# Epoch 00006: val_accuracy improved from 0.67868 to 0.69128, saving model to model_weights.h5
# Epoch 7/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.5448 - accuracy: 0.7671 - val_loss: 0.7185 - val_accuracy: 0.6789
#
# Epoch 00007: val_accuracy did not improve from 0.69128
# Epoch 8/25
# 250/250 [==============================] - 52s 207ms/step - loss: 0.4900 - accuracy: 0.7945 - val_loss: 0.7875 - val_accuracy: 0.6454
#
# Epoch 00008: val_accuracy did not improve from 0.69128
# Epoch 9/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.4703 - accuracy: 0.8037 - val_loss: 0.8566 - val_accuracy: 0.6391
#
# Epoch 00009: val_accuracy did not improve from 0.69128
# Epoch 10/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.4284 - accuracy: 0.8257 - val_loss: 0.6874 - val_accuracy: 0.7127
#
# Epoch 00010: val_accuracy improved from 0.69128 to 0.71270, saving model to model_weights.h5
# Epoch 11/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.3896 - accuracy: 0.8410 - val_loss: 0.7174 - val_accuracy: 0.6971
#
# Epoch 00011: val_accuracy did not improve from 0.71270
# Epoch 12/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.3674 - accuracy: 0.8491 - val_loss: 0.6645 - val_accuracy: 0.7326
#
# Epoch 00012: val_accuracy improved from 0.71270 to 0.73261, saving model to model_weights.h5
# Epoch 13/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.3330 - accuracy: 0.8656 - val_loss: 0.8703 - val_accuracy: 0.6691
#
# Epoch 00013: val_accuracy did not improve from 0.73261
# Epoch 14/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.3137 - accuracy: 0.8769 - val_loss: 0.7063 - val_accuracy: 0.7135
#
# Epoch 00014: val_accuracy did not improve from 0.73261
# Epoch 15/25
# 250/250 [==============================] - 52s 206ms/step - loss: 0.2588 - accuracy: 0.8983 - val_loss: 0.9458 - val_accuracy: 0.6467
#
# Epoch 00015: val_accuracy did not improve from 0.73261
# Epoch 16/25
# 250/250 [==============================] - 51s 205ms/step - loss: 0.2349 - accuracy: 0.9112 - val_loss: 0.8023 - val_accuracy: 0.7218
#
# Epoch 00016: val_accuracy did not improve from 0.73261
# Epoch 17/25
# 250/250 [==============================] - 52s 207ms/step - loss: 0.2186 - accuracy: 0.9158 - val_loss: 0.9210 - val_accuracy: 0.7094
#
# Epoch 00017: val_accuracy did not improve from 0.73261
# Epoch 18/25
# 250/250 [==============================] - 52s 207ms/step - loss: 0.1782 - accuracy: 0.9319 - val_loss: 0.9526 - val_accuracy: 0.6941
#
# Epoch 00018: val_accuracy did not improve from 0.73261
# Epoch 19/25
# 250/250 [==============================] - 52s 207ms/step - loss: 0.1964 - accuracy: 0.9278 - val_loss: 0.8639 - val_accuracy: 0.7165
#
# Epoch 00019: val_accuracy did not improve from 0.73261
# Epoch 20/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.1440 - accuracy: 0.9464 - val_loss: 0.9882 - val_accuracy: 0.7112
#
# Epoch 00020: val_accuracy did not improve from 0.73261
# Epoch 21/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.1155 - accuracy: 0.9594 - val_loss: 0.9971 - val_accuracy: 0.7276
#
# Epoch 00021: val_accuracy did not improve from 0.73261
# Epoch 22/25
# 250/250 [==============================] - 51s 205ms/step - loss: 0.1245 - accuracy: 0.9575 - val_loss: 1.0863 - val_accuracy: 0.7251
#
# Epoch 00022: val_accuracy did not improve from 0.73261
# Epoch 23/25
# 250/250 [==============================] - 52s 207ms/step - loss: 0.0974 - accuracy: 0.9677 - val_loss: 1.1761 - val_accuracy: 0.6880
#
# Epoch 00023: val_accuracy did not improve from 0.73261
# Epoch 24/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.0972 - accuracy: 0.9620 - val_loss: 1.2310 - val_accuracy: 0.7220
#
# Epoch 00024: val_accuracy did not improve from 0.73261
# Epoch 25/25
# 250/250 [==============================] - 51s 206ms/step - loss: 0.0932 - accuracy: 0.9671 - val_loss: 1.2221 - val_accuracy: 0.6762
#
# Epoch 00025: val_accuracy did not improve from 0.73261

# %%
#looking at loss/accuracy plots
plt.figure()
plt.ylabel('Loss',fontsize=16)
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Testing loss')
plt.legend(loc='upper right')

# plt.subplot(1,2,2)
plt.figure()
plt.ylabel('Accuracy',fontsize=16)
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Testing Accuracy')
plt.legend(loc='lower right')

plt.show()

# %%
#confusion matrix
predictions = model.predict_generator(generator=test_generator)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm,classes,title='Confusion matirx',cmap=plt.cm.Blues):
    cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm,interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f'
    thresh = cm.max()/2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    pass

cnf_mat = confusion_matrix(y_test,y_pred)
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_mat, classes=class_names, title='Normalized Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
#looking at test accuracy
test_acc = model.evaluate_generator(test_generator)
print("Test accuracy: ",test_acc[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1948: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Test accuracy:  0.676551878452301
